# %% [markdown]
# # Progree is rapid and has been for a long time.
# - GPT(2018) Simple tasks with generative pretrained transformer.
# - GPT 2 (2019) Expressive long form coherent text generation.
# - GPT 3 (2020) Language models are used few short learners : Problem solving.
# - Web GPT(2021) Language models can use tools like web search.
# - Instruct GPT(2022) Improved problem solving and safety through human instruction.
# - Chat GPT(2022) Extraordinary interactivity and text generation.
